# %% [markdown]
# # Avazu - Click-Through Rate Prediction

# %% [markdown]
# Julia Kang - jkang613@gmail.com - AMLI 2019 - Mills College

# %% [markdown]
# References: https://towardsdatascience.com/mobile-ads-click-through-rate-ctr-prediction-44fdac40c6ff

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import multiprocessing as mp
import psutil
import random
import datetime as datetime
import matplotlib.pyplot as plt

# %% [markdown]
# # Load in Data

# %%
#read in the original csv file

# df = pd.read_csv('../data/train_sample.csv')

# df.head()
# Out:
#                      id  click      hour    C1  banner_pos   site_id  \
# 0   1000009418151094273      0  14102100  1005           0  1fbe01fe
# 1  10000169349117863715      0  14102100  1005           0  1fbe01fe
# 2  10000371904215119486      0  14102100  1005           0  1fbe01fe
# 3  10000640724480838376      0  14102100  1005           0  1fbe01fe
# 4  10000679056417042096      0  14102100  1005           1  fe8cc448
#
#   site_domain site_category    app_id app_domain  ... device_type  \
# 0    f3845767      28905ebd  ecad2386   7801e8d9  ...           1
# 1    f3845767      28905ebd  ecad2386   7801e8d9  ...           1
# 2    f3845767      28905ebd  ecad2386   7801e8d9  ...           1
# 3    f3845767      28905ebd  ecad2386   7801e8d9  ...           1
# 4    9166c161      0569f928  ecad2386   7801e8d9  ...           1
#
#   device_conn_type    C14  C15  C16   C17  C18  C19     C20  C21
# 0                2  15706  320   50  1722    0   35      -1   79
# 1                0  15704  320   50  1722    0   35  100084   79
# 2                0  15704  320   50  1722    0   35  100084   79
# 3                0  15706  320   50  1722    0   35  100084   79
# 4                0  18993  320   50  2161    0   35      -1  157
#
# [5 rows x 24 columns]

# %%
# Check the number of cores and memory usage
# num_cores = mp.cpu_count()
# print("This kernel has ",num_cores,"cores and you can find the information regarding the memory usage:",psutil.virtual_memory())
# Out:
# This kernel has  2 cores and you can find the information regarding the memory usage: svmem(total=13660774400, available=12822257664, percent=6.1, used=564858880, free=12662702080, active=617058304, inactive=273485824, buffers=41693184, cached=391520256, shared=10665984, slab=47509504)

# %%
# p = 0.01  # 1% of the lines
# # keep the header, then take only 1% of lines
# # if random from [0,1] interval is greater than 0.01 the row will be skipped
# filename = '../data/train_ds.csv'

# df_new = pd.read_csv(
#          filename,
#          header=0, 
#          skiprows=lambda i: i>0 and random.random() > p
)

# %%
#view the shape of the randomly selected sample we generated
# df_new.shape
# Out:
# (404410, 24)

# %%
# df_new.head()
# Out:
#                      id  click      hour    C1  banner_pos   site_id  \
# 0  10004510652136496837      0  14102100  1005           0  543a539e
# 1  10007164336863914220      1  14102100  1005           0  1fbe01fe
# 2  10076859283156800622      0  14102100  1002           0  f17ebd97
# 3  10078825124049580646      0  14102100  1005           0  1fbe01fe
# 4  10085233430943183912      0  14102100  1005           0  1fbe01fe
#
#   site_domain site_category    app_id app_domain  ... device_type  \
# 0    c7ca3108      3e814130  ecad2386   7801e8d9  ...           1
# 1    f3845767      28905ebd  ecad2386   7801e8d9  ...           1
# 2    c4e18dd6      50e219e0  ecad2386   7801e8d9  ...           0
# 3    f3845767      28905ebd  ecad2386   7801e8d9  ...           1
# 4    f3845767      28905ebd  ecad2386   7801e8d9  ...           1
#
#   device_conn_type    C14  C15  C16   C17  C18  C19     C20  C21
# 0                0  20352  320   50  2333    0   39      -1  157
# 1                0  15706  320   50  1722    0   35      -1   79
# 2                0  21692  216   36  2497    3   43  100151   42
# 3                0  15705  320   50  1722    0   35      -1   79
# 4                0  15701  320   50  1722    0   35      -1   79
#
# [5 rows x 24 columns]

# %%
#create new csv that is randomly sampled from originally training set that has 404,410 rows - it's been moved to the
#data folder

# df_new.to_csv("rand_sample_csv.csv")

# %%
#read the csv file we created and make sure to pass the 'hour' column as the correct dtype

sub_df = pd.read_csv('rand_sample_csv.csv', parse_dates=['hour'])

# %%
sub_df.head() #preview the data
# Out:
#    Unnamed: 0                    id  click      hour    C1  banner_pos  \
# 0           0  10004510652136496837      0  14102100  1005           0
# 1           1  10007164336863914220      1  14102100  1005           0
# 2           2  10076859283156800622      0  14102100  1002           0
# 3           3  10078825124049580646      0  14102100  1005           0
# 4           4  10085233430943183912      0  14102100  1005           0
#
#     site_id site_domain site_category    app_id ...  device_type  \
# 0  543a539e    c7ca3108      3e814130  ecad2386 ...            1
# 1  1fbe01fe    f3845767      28905ebd  ecad2386 ...            1
# 2  f17ebd97    c4e18dd6      50e219e0  ecad2386 ...            0
# 3  1fbe01fe    f3845767      28905ebd  ecad2386 ...            1
# 4  1fbe01fe    f3845767      28905ebd  ecad2386 ...            1
#
#   device_conn_type    C14  C15 C16   C17  C18  C19     C20  C21
# 0                0  20352  320  50  2333    0   39      -1  157
# 1                0  15706  320  50  1722    0   35      -1   79
# 2                0  21692  216  36  2497    3   43  100151   42
# 3                0  15705  320  50  1722    0   35      -1   79
# 4                0  15701  320  50  1722    0   35      -1   79
#
# [5 rows x 25 columns]

# %%
sub_df.columns #read through the column names so we can delete the first column since it is useless
sub_df = sub_df.drop('Unnamed: 0', axis = 1)

# %%
sub_df.head() #check to make sure the column deletion was successful
# Out:
#                      id  click      hour    C1  banner_pos   site_id  \
# 0  10004510652136496837      0  14102100  1005           0  543a539e
# 1  10007164336863914220      1  14102100  1005           0  1fbe01fe
# 2  10076859283156800622      0  14102100  1002           0  f17ebd97
# 3  10078825124049580646      0  14102100  1005           0  1fbe01fe
# 4  10085233430943183912      0  14102100  1005           0  1fbe01fe
#
#   site_domain site_category    app_id app_domain ...  device_type  \
# 0    c7ca3108      3e814130  ecad2386   7801e8d9 ...            1
# 1    f3845767      28905ebd  ecad2386   7801e8d9 ...            1
# 2    c4e18dd6      50e219e0  ecad2386   7801e8d9 ...            0
# 3    f3845767      28905ebd  ecad2386   7801e8d9 ...            1
# 4    f3845767      28905ebd  ecad2386   7801e8d9 ...            1
#
#   device_conn_type    C14  C15  C16   C17  C18  C19     C20  C21
# 0                0  20352  320   50  2333    0   39      -1  157
# 1                0  15706  320   50  1722    0   35      -1   79
# 2                0  21692  216   36  2497    3   43  100151   42
# 3                0  15705  320   50  1722    0   35      -1   79
# 4                0  15701  320   50  1722    0   35      -1   79
#
# [5 rows x 24 columns]

# %%
# sub_df['date'], sub_df['time'] = sub_df['hour'].str[:6], sub_df['hour'][6:]

# %%
# feature engineering - work on the hour column and separate the hour and time into new columns
parse_date = lambda val : pd.datetime.strptime(val, '%y%m%d%H')
sub_df['new_hour'] = sub_df['hour'].apply(parse_date)
sub_df['new_hour']
# Out:
# 0        2014-10-21 00:00:00
# 1        2014-10-21 00:00:00
# 2        2014-10-21 00:00:00
# 3        2014-10-21 00:00:00
# 4        2014-10-21 00:00:00
# 5        2014-10-21 00:00:00
# 6        2014-10-21 00:00:00
# 7        2014-10-21 00:00:00
# 8        2014-10-21 00:00:00
# 9        2014-10-21 00:00:00
# 10       2014-10-21 00:00:00
# 11       2014-10-21 00:00:00
# 12       2014-10-21 00:00:00
# 13       2014-10-21 00:00:00
# 14       2014-10-21 00:00:00
# 15       2014-10-21 00:00:00
# 16       2014-10-21 00:00:00
# 17       2014-10-21 00:00:00
# 18       2014-10-21 00:00:00
# 19       2014-10-21 00:00:00
# 20       2014-10-21 00:00:00
# 21       2014-10-21 00:00:00
# 22       2014-10-21 00:00:00
# 23       2014-10-21 00:00:00
# 24       2014-10-21 00:00:00
# 25       2014-10-21 00:00:00
# 26       2014-10-21 00:00:00
# 27       2014-10-21 00:00:00
# 28       2014-10-21 00:00:00
# 29       2014-10-21 00:00:00
#                  ...
# 404380   2014-10-30 23:00:00
# 404381   2014-10-30 23:00:00
# 404382   2014-10-30 23:00:00
# 404383   2014-10-30 23:00:00
# 404384   2014-10-30 23:00:00
# 404385   2014-10-30 23:00:00
# 404386   2014-10-30 23:00:00
# 404387   2014-10-30 23:00:00
# 404388   2014-10-30 23:00:00
# 404389   2014-10-30 23:00:00
# 404390   2014-10-30 23:00:00
# 404391   2014-10-30 23:00:00
# 404392   2014-10-30 23:00:00
# 404393   2014-10-30 23:00:00
# 404394   2014-10-30 23:00:00
# 404395   2014-10-30 23:00:00
# 404396   2014-10-30 23:00:00
# 404397   2014-10-30 23:00:00
# 404398   2014-10-30 23:00:00
# 404399   2014-10-30 23:00:00
# 404400   2014-10-30 23:00:00
# 404401   2014-10-30 23:00:00
# 404402   2014-10-30 23:00:00
# 404403   2014-10-30 23:00:00
# 404404   2014-10-30 23:00:00
# 404405   2014-10-30 23:00:00
# 404406   2014-10-30 23:00:00
# 404407   2014-10-30 23:00:00
# 404408   2014-10-30 23:00:00
# 404409   2014-10-30 23:00:00
# Name: new_hour, Length: 404410, dtype: datetime64[ns]

# %%
sub_df['new_date'] = [d.date() for d in sub_df['new_hour']]
sub_df['new_time'] = [d.time() for d in sub_df['new_hour']]

# %%
sub_df.head() #check if column creation was successful
# Out:
#                      id  click      hour    C1  banner_pos   site_id  \
# 0  10004510652136496837      0  14102100  1005           0  543a539e
# 1  10007164336863914220      1  14102100  1005           0  1fbe01fe
# 2  10076859283156800622      0  14102100  1002           0  f17ebd97
# 3  10078825124049580646      0  14102100  1005           0  1fbe01fe
# 4  10085233430943183912      0  14102100  1005           0  1fbe01fe
#
#   site_domain site_category    app_id app_domain    ...     C15 C16   C17 C18  \
# 0    c7ca3108      3e814130  ecad2386   7801e8d9    ...     320  50  2333   0
# 1    f3845767      28905ebd  ecad2386   7801e8d9    ...     320  50  1722   0
# 2    c4e18dd6      50e219e0  ecad2386   7801e8d9    ...     216  36  2497   3
# 3    f3845767      28905ebd  ecad2386   7801e8d9    ...     320  50  1722   0
# 4    f3845767      28905ebd  ecad2386   7801e8d9    ...     320  50  1722   0
#
#    C19     C20  C21   new_hour    new_date  new_time
# 0   39      -1  157 2014-10-21  2014-10-21  00:00:00
# 1   35      -1   79 2014-10-21  2014-10-21  00:00:00
# 2   43  100151   42 2014-10-21  2014-10-21  00:00:00
# 3   35      -1   79 2014-10-21  2014-10-21  00:00:00
# 4   35      -1   79 2014-10-21  2014-10-21  00:00:00
#
# [5 rows x 27 columns]

# %%
sub_df = sub_df.drop('new_hour', axis = 1) #drop the 'new_hour' column do eliminate redundancy

# %%
sub_df.head()
# Out:
#                      id  click      hour    C1  banner_pos   site_id  \
# 0  10004510652136496837      0  14102100  1005           0  543a539e
# 1  10007164336863914220      1  14102100  1005           0  1fbe01fe
# 2  10076859283156800622      0  14102100  1002           0  f17ebd97
# 3  10078825124049580646      0  14102100  1005           0  1fbe01fe
# 4  10085233430943183912      0  14102100  1005           0  1fbe01fe
#
#   site_domain site_category    app_id app_domain    ...       C14  C15 C16  \
# 0    c7ca3108      3e814130  ecad2386   7801e8d9    ...     20352  320  50
# 1    f3845767      28905ebd  ecad2386   7801e8d9    ...     15706  320  50
# 2    c4e18dd6      50e219e0  ecad2386   7801e8d9    ...     21692  216  36
# 3    f3845767      28905ebd  ecad2386   7801e8d9    ...     15705  320  50
# 4    f3845767      28905ebd  ecad2386   7801e8d9    ...     15701  320  50
#
#     C17  C18  C19     C20  C21    new_date  new_time
# 0  2333    0   39      -1  157  2014-10-21  00:00:00
# 1  1722    0   35      -1   79  2014-10-21  00:00:00
# 2  2497    3   43  100151   42  2014-10-21  00:00:00
# 3  1722    0   35      -1   79  2014-10-21  00:00:00
# 4  1722    0   35      -1   79  2014-10-21  00:00:00
#
# [5 rows x 26 columns]

# %%
sub_df.to_csv("julia_rand_sample_hour.csv") #export as a csv so save for future use

# sub_df = sub_df = pd.read_csv('julia_rand_sample_csv.csv')

# %%
# sub_df = sub_df.drop('hour', axis = 1)

# %%
sub_df.head()
# Out:
#                      id  click      hour    C1  banner_pos   site_id  \
# 0  10004510652136496837      0  14102100  1005           0  543a539e
# 1  10007164336863914220      1  14102100  1005           0  1fbe01fe
# 2  10076859283156800622      0  14102100  1002           0  f17ebd97
# 3  10078825124049580646      0  14102100  1005           0  1fbe01fe
# 4  10085233430943183912      0  14102100  1005           0  1fbe01fe
#
#   site_domain site_category    app_id app_domain    ...       C14  C15 C16  \
# 0    c7ca3108      3e814130  ecad2386   7801e8d9    ...     20352  320  50
# 1    f3845767      28905ebd  ecad2386   7801e8d9    ...     15706  320  50
# 2    c4e18dd6      50e219e0  ecad2386   7801e8d9    ...     21692  216  36
# 3    f3845767      28905ebd  ecad2386   7801e8d9    ...     15705  320  50
# 4    f3845767      28905ebd  ecad2386   7801e8d9    ...     15701  320  50
#
#     C17  C18  C19     C20  C21    new_date  new_time
# 0  2333    0   39      -1  157  2014-10-21  00:00:00
# 1  1722    0   35      -1   79  2014-10-21  00:00:00
# 2  2497    3   43  100151   42  2014-10-21  00:00:00
# 3  1722    0   35      -1   79  2014-10-21  00:00:00
# 4  1722    0   35      -1   79  2014-10-21  00:00:00
#
# [5 rows x 26 columns]

# %%
#check for null and empty values - There are none
sub_df.isnull().sum()
# Out:
# id                  0
# click               0
# hour                0
# C1                  0
# banner_pos          0
# site_id             0
# site_domain         0
# site_category       0
# app_id              0
# app_domain          0
# app_category        0
# device_id           0
# device_ip           0
# device_model        0
# device_type         0
# device_conn_type    0
# C14                 0
# C15                 0
# C16                 0
# C17                 0
# C18                 0
# C19                 0
# C20                 0
# C21                 0
# new_date            0
# new_time            0
# dtype: int64

# %% [markdown]
# ## Clicks

# %%
#see what percentage of people click and what percentage of people do not click
# click = 16.9991% no click = 83.0009%
sub_df['click'].value_counts()/404410
# Out:
# 0    0.830009
# 1    0.169991
# Name: click, dtype: float64

# %%
#Find the start and end date of the data
print(sub_df['new_date'].min(), sub_df['new_date'].max())
# Out:
# 2014-10-21 2014-10-30

# %% [markdown]
# Our dataset ranges from 10/21/2014 to 10/30/2014. It spans a total of 10 days.

# %%
clicks = sub_df.groupby('hour').agg({'click':'sum'})
clicks
# Out:
#           click
# hour
# 14102100    215
# 14102101    251
# 14102102    308
# 14102103    304
# 14102104    366
# 14102105    397
# 14102106    383
# 14102107    351
# 14102108    362
# 14102109    372
# 14102110    334
# 14102111    365
# 14102112    299
# 14102113    371
# 14102114    372
# 14102115    341
# 14102116    327
# 14102117    337
# 14102118    273
# 14102119    209
# 14102120    170
# 14102121    160
# 14102122    154
# 14102123    147
# 14102200    135
# 14102201    155
# 14102202    169
# 14102203    288
# 14102204    363
# 14102205    409
# ...         ...
# 14102918    213
# 14102919    178
# 14102920    190
# 14102921    143
# 14102922    156
# 14102923    176
# 14103000    171
# 14103001    186
# 14103002    201
# 14103003    211
# 14103004    348
# 14103005    346
# 14103006    293
# 14103007    306
# 14103008    304
# 14103009    353
# 14103010    357
# 14103011    401
# 14103012    384
# 14103013    391
# 14103014    419
# 14103015    450
# 14103016    398
# 14103017    338
# 14103018    329
# 14103019    252
# 14103020    195
# 14103021    251
# 14103022    165
# 14103023    129
#
# [240 rows x 1 columns]

# %%
plt.plot(clicks)
plt.ylabel('Number of clicks')
plt.title('Total Click Activity')
#Change x-axis
# Out:
# Text(0.5,1,'Total Click Activity')

# %%
clicks_details = sub_df.groupby(['new_date','new_time']).size().unstack()
clicks_details
# Out:
# new_time    00:00:00  01:00:00  02:00:00  03:00:00  04:00:00  05:00:00  \
# new_date
# 2014-10-21      1182      1400      2061      1875      2611      2673
# 2014-10-22       794       926      1011      1376      2020      2892
# 2014-10-23       879      1052      1533      1777      2777      2257
# 2014-10-24       789       927      1213      1228      1644      1664
# 2014-10-25       726       795       402       675       762      1209
# 2014-10-26       720       828       991      1106      1507      1725
# 2014-10-27       646       738       847      1190      1348      1730
# 2014-10-28       811      1040      1750      1178      1376      1753
# 2014-10-29      1000      1176      1404      2305      1588      1299
# 2014-10-30       888       890       944      1244      3436      2525
#
# new_time    06:00:00  07:00:00  08:00:00  09:00:00    ...     14:00:00  \
# new_date                                              ...
# 2014-10-21      2395      2077      2116      2282    ...         1786
# 2014-10-22      2881      2244      3227      4442    ...         1798
# 2014-10-23      1400      1563      2381      1811    ...         1745
# 2014-10-24      1644      1769      1676      1725    ...         2160
# 2014-10-25       514      1374      1546      1795    ...         2394
# 2014-10-26      1773      1922      1917      2090    ...         2323
# 2014-10-27      1807      1692      1607      1522    ...         1062
# 2014-10-28      1804      2085      2858      3278    ...         3898
# 2014-10-29      1397      2317      2034      1921    ...         2255
# 2014-10-30      1877      1620      1648      1890    ...         2607
#
# new_time    15:00:00  16:00:00  17:00:00  18:00:00  19:00:00  20:00:00  \
# new_date
# 2014-10-21      1767      1767      1668      1527      1246      1062
# 2014-10-22      1823      1886      1984      2113      1772      1491
# 2014-10-23      2477      1690      1601      1494      1394      1355
# 2014-10-24      2029      2624      2513      1636       310       200
# 2014-10-25      2515      2105      2111      1930      1215      1004
# 2014-10-26      2013      1980      1873      1530      1185      1014
# 2014-10-27      1075      1788      2356      2089      1590      1016
# 2014-10-28      2817      2849      2886      2363      1991      1682
# 2014-10-29      2028      1825      1588      1369      1241      1157
# 2014-10-30      2396      2071      1849      1674      1259      1140
#
# new_time    21:00:00  22:00:00  23:00:00
# new_date
# 2014-10-21       922       830       744
# 2014-10-22      1215      1078       938
# 2014-10-23      1224      1049       895
# 2014-10-24       238       144       246
# 2014-10-25       896       863       800
# 2014-10-26       815       879       809
# 2014-10-27       963       950       871
# 2014-10-28      1582      1253      1167
# 2014-10-29       954       942       977
# 2014-10-30      1076      1053       846
#
# [10 rows x 24 columns]

# %%
plt.plot(clicks_details)
plt.figsize=(24,12)
plt.ylabel('Number of clicks')
plt.title('Number of clicks trends per hour per day') 
plt.show()

# %%
clicks_per_hour = sub_df.groupby('new_time').agg({'click': 'sum'})

# %%
plt.plot(clicks_per_hour)
plt.ylabel('Number of clicks')
plt.title('Number of clicks trends per hour') 
plt.figsize=(12,6)

# %% [markdown]
# ## Impressions

# %%
# ORDER MATTERS
click_per_view_per_hour = sub_df.groupby(['new_time','click']).size().unstack()
click_per_view_per_hour
# Out:
# click         0     1
# new_time
# 00:00:00   6903  1532
# 01:00:00   7938  1834
# 02:00:00  10016  2140
# 03:00:00  11427  2527
# 04:00:00  16044  3025
# 05:00:00  16546  3181
# 06:00:00  14624  2868
# 07:00:00  15339  3324
# 08:00:00  17548  3462
# 09:00:00  19182  3574
# 10:00:00  18128  3429
# 11:00:00  16978  3610
# 12:00:00  18116  3839
# 13:00:00  19993  4033
# 14:00:00  18167  3861
# 15:00:00  17141  3799
# 16:00:00  16858  3727
# 17:00:00  16873  3556
# 18:00:00  14712  3013
# 19:00:00  11038  2165
# 20:00:00   9339  1782
# 21:00:00   8311  1574
# 22:00:00   7542  1499
# 23:00:00   6901  1392

# %%
# plt.plot(click_per_view_per_hour, figsize = (12,6))
plt.plot(click_per_view_per_hour)
plt.ylabel('Impressions')
plt.xlabel('Time')
plt.title('Hourly Impressions vs. clicks')

#Can't get it to a bar graph...?
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-7f2a850efa1d> in <module>()
#       1 # plt.plot(click_per_view_per_hour, figsize = (12,6))
# ----> 2 plt.plot(click_per_view_per_hour).plot(kind ='bar')
#       3 plt.ylabel('Impressions')
#       4 plt.xlabel('Time')
#       5 plt.title('Hourly Impressions vs. clicks')
#
# AttributeError: 'list' object has no attribute 'plot'

# %% [markdown]
# ## Hourly CTR
